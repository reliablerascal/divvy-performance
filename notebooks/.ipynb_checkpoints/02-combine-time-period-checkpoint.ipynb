# %% [markdown]
# <h1>Combine Time Periods into One Dataset</h1>
# 11/17/23<br>
# This notebook appends snapshots of Divvy station status with similar file names (e.g. station_status_2023_11_16*.csv) and appends them into one csv<br>

# %% [markdown]
# ### next steps
# in api-request.py, should rename timestamp to time_reported and remove that code here

# %% [markdown]
# # Define Time Period to Combine

# %%
#update this to combine different files
filename_import = "station_status_2023_11_17*.csv"
filename_export = "station-status-hourly-2023-11-17.csv"

# %% [markdown]
# # import libraries

# %%
import pandas as pd
import requests
from datetime import datetime
from pathlib import Path

# %% [markdown]
# # import station info

# %%
url = f"https://gbfs.lyft.com/gbfs/2.3/chi/en/station_information.json?"

#request data
response = requests.get(url)
data = response.json()
response
# Out:
# <Response [200]>

# %%
df_station_info = pd.DataFrame(data['data']['stations'], columns=['station_id','name','lat','lon','capacity'])
df_station_info.head()
# Out:
#                              station_id                          name  \
# 0  a3a82c6c-a135-11e9-9cda-0a87ae2ba916  Southport Ave & Waveland Ave
# 1  a3b48c07-a135-11e9-9cda-0a87ae2ba916      Leavitt St & Chicago Ave
# 2  a3a48d5c-a135-11e9-9cda-0a87ae2ba916      Elston Ave & Cortland St
# 3  a3ac7e9a-a135-11e9-9cda-0a87ae2ba916          Racine Ave & 35th St
# 4  a3a62aad-a135-11e9-9cda-0a87ae2ba916      Loomis St & Jackson Blvd
#
#          lat        lon  capacity
# 0  41.948150 -87.663940        23
# 1  41.895501 -87.682017        19
# 2  41.916433 -87.666746        23
# 3  41.830689 -87.656211        15
# 4  41.877945 -87.662007        19

# %% [markdown]
# # import all data files matching specified pattern

# %%
df_station_status = pd.DataFrame()

# %%
for file_path in Path('../data').glob(filename_import):
    #read next file
    df = pd.read_csv(file_path)
    
    #timestamp for data retrieval. This should later be moved to the api-request.py script called in GitHub actions
    time_retrieved_str = file_path.name[15:32]

    date_object = datetime.strptime(time_retrieved_str, '%Y_%m_%d_%I%M%p')
    time_retrieved = date_object.strftime('%m/%d/%Y %I:%M %p')
    
    df["time_retrieved"]= time_retrieved
    df.rename(columns={'timestamp': 'time_reported'}, inplace=True)
    
    #append this file
    df_station_status = pd.concat([df_station_status,df], ignore_index=True)
df_station_status
# Out:
#        num_bikes_disabled  num_scooters_available  num_docks_available  \
# 0                       1                     0.0                    6
# 1                       0                     0.0                    4
# 2                       0                     1.0                    7
# 3                       1                     0.0                   17
# 4                       0                     0.0                    1
# ...                   ...                     ...                  ...
# 16655                   0                     NaN                    1
# 16656                   0                     0.0                    7
# 16657                   0                     NaN                    2
# 16658                   0                     NaN                    4
# 16659                   0                     NaN                    2
#
#        num_docks_disabled  is_installed  is_renting  num_bikes_available  \
# 0                       0             1           1                    4
# 1                       0             1           1                    7
# 2                       0             1           1                    6
# 3                       0             1           1                    1
# 4                       0             1           1                   10
# ...                   ...           ...         ...                  ...
# 16655                   0             1           1                    0
# 16656                   0             1           1                    2
# 16657                   0             1           1                    0
# 16658                   0             1           1                    0
# 16659                   0             1           1                    0
#
#        num_scooters_unavailable  num_ebikes_available  \
# 0                           0.0                     0
# 1                           0.0                     1
# 2                           1.0                     0
# 3                           0.0                     0
# 4                           0.0                     1
# ...                         ...                   ...
# 16655                       NaN                     0
# 16656                       0.0                     2
# 16657                       NaN                     0
# 16658                       NaN                     0
# 16659                       NaN                     0
#
#                                  station_id  is_returning  \
# 0      a3b2862e-a135-11e9-9cda-0a87ae2ba916             1
# 1      da9e6779-5056-4d45-bae3-9dc325ed2807             1
# 2      a3a3f0c6-a135-11e9-9cda-0a87ae2ba916             1
# 3      a3a795d7-a135-11e9-9cda-0a87ae2ba916             1
# 4      a3b2be3a-a135-11e9-9cda-0a87ae2ba916             1
# ...                                     ...           ...
# 16655                   1715823822654071770             1
# 16656                   1563698701206292480             1
# 16657                   1674190591734328324             1
# 16658                   1806749735787774444             1
# 16659                   1674190634684001360             1
#
#              time_reported  n_classic  n_electric  n_scooters  \
# 0      11/17/2023 01:03 AM          4           0           0
# 1      11/17/2023 01:03 AM          6           1           0
# 2      11/17/2023 01:03 AM          6           0           1
# 3      11/17/2023 01:03 AM          1           0           0
# 4      11/17/2023 01:03 AM          9           1           0
# ...                    ...        ...         ...         ...
# 16655  01/22/2023 09:45 PM          0           0           0
# 16656  01/22/2023 09:44 PM          0           0           0
# 16657  01/22/2023 09:46 PM          0           0           0
# 16658  05/04/2023 12:50 PM          0           0           0
# 16659  01/22/2023 09:45 PM          0           0           0
#
#             time_retrieved
# 0      11/17/2023 01:05 AM
# 1      11/17/2023 01:05 AM
# 2      11/17/2023 01:05 AM
# 3      11/17/2023 01:05 AM
# 4      11/17/2023 01:05 AM
# ...                    ...
# 16655  11/17/2023 12:09 AM
# 16656  11/17/2023 12:09 AM
# 16657  11/17/2023 12:09 AM
# 16658  11/17/2023 12:09 AM
# 16659  11/17/2023 12:09 AM
#
# [16660 rows x 16 columns]

# %% [markdown]
# # Prepare Data for Analysis

# %% [markdown]
# ### calculate key metrics

# %%
#add calculated columns
df_station_status['is_no_classic']=(df_station_status['n_classic']==0)
df_station_status['is_no_docks']=(df_station_status['num_docks_available']==0)
df_station_status['is_problem_station']= df_station_status['is_no_classic'] | df_station_status['is_no_docks']

df_station_status.head()
# Out:
#    num_bikes_disabled  num_scooters_available  num_docks_available  \
# 0                   1                     0.0                    6
# 1                   0                     0.0                    4
# 2                   0                     1.0                    7
# 3                   1                     0.0                   17
# 4                   0                     0.0                    1
#
#    num_docks_disabled  is_installed  is_renting  num_bikes_available  \
# 0                   0             1           1                    4
# 1                   0             1           1                    7
# 2                   0             1           1                    6
# 3                   0             1           1                    1
# 4                   0             1           1                   10
#
#    num_scooters_unavailable  num_ebikes_available  \
# 0                       0.0                     0
# 1                       0.0                     1
# 2                       1.0                     0
# 3                       0.0                     0
# 4                       0.0                     1
#
#                              station_id  is_returning        time_reported  \
# 0  a3b2862e-a135-11e9-9cda-0a87ae2ba916             1  11/17/2023 01:03 AM
# 1  da9e6779-5056-4d45-bae3-9dc325ed2807             1  11/17/2023 01:03 AM
# 2  a3a3f0c6-a135-11e9-9cda-0a87ae2ba916             1  11/17/2023 01:03 AM
# 3  a3a795d7-a135-11e9-9cda-0a87ae2ba916             1  11/17/2023 01:03 AM
# 4  a3b2be3a-a135-11e9-9cda-0a87ae2ba916             1  11/17/2023 01:03 AM
#
#    n_classic  n_electric  n_scooters       time_retrieved  is_no_classic  \
# 0          4           0           0  11/17/2023 01:05 AM          False
# 1          6           1           0  11/17/2023 01:05 AM          False
# 2          6           0           1  11/17/2023 01:05 AM          False
# 3          1           0           0  11/17/2023 01:05 AM          False
# 4          9           1           0  11/17/2023 01:05 AM          False
#
#    is_no_docks  is_problem_station
# 0        False               False
# 1        False               False
# 2        False               False
# 3        False               False
# 4        False               False

# %% [markdown]
# # Merge Station Info

# %%
df_stations = pd.merge(df_station_status, df_station_info, on='station_id')
df_stations.head()
# Out:
#    num_bikes_disabled  num_scooters_available  num_docks_available  \
# 0                   1                     0.0                    6
# 1                   1                     0.0                    6
# 2                   1                     0.0                    6
# 3                   1                     0.0                    6
# 4                   1                     0.0                    6
#
#    num_docks_disabled  is_installed  is_renting  num_bikes_available  \
# 0                   0             1           1                    4
# 1                   0             1           1                    4
# 2                   0             1           1                    4
# 3                   0             1           1                    4
# 4                   0             1           1                    4
#
#    num_scooters_unavailable  num_ebikes_available  \
# 0                       0.0                     0
# 1                       0.0                     0
# 2                       0.0                     0
# 3                       0.0                     0
# 4                       0.0                     0
#
#                              station_id  ...  n_electric n_scooters  \
# 0  a3b2862e-a135-11e9-9cda-0a87ae2ba916  ...           0          0
# 1  a3b2862e-a135-11e9-9cda-0a87ae2ba916  ...           0          0
# 2  a3b2862e-a135-11e9-9cda-0a87ae2ba916  ...           0          0
# 3  a3b2862e-a135-11e9-9cda-0a87ae2ba916  ...           0          0
# 4  a3b2862e-a135-11e9-9cda-0a87ae2ba916  ...           0          0
#
#         time_retrieved  is_no_classic  is_no_docks is_problem_station  \
# 0  11/17/2023 01:05 AM          False        False              False
# 1  11/17/2023 02:07 AM          False        False              False
# 2  11/17/2023 03:06 AM          False        False              False
# 3  11/17/2023 04:06 AM          False        False              False
# 4  11/17/2023 05:05 AM          False        False              False
#
#                     name        lat        lon capacity
# 0  Bennett Ave & 79th St  41.751785 -87.578496       11
# 1  Bennett Ave & 79th St  41.751785 -87.578496       11
# 2  Bennett Ave & 79th St  41.751785 -87.578496       11
# 3  Bennett Ave & 79th St  41.751785 -87.578496       11
# 4  Bennett Ave & 79th St  41.751785 -87.578496       11
#
# [5 rows x 23 columns]

# %%
#identify and remove public racks
df_stations['is_public_rack']=df_stations['name'].str[:11]=='Public Rack'
df_stations_divvy = df_stations[df_stations['is_public_rack']==False]
df_stations_divvy
# Out:
#        num_bikes_disabled  num_scooters_available  num_docks_available  \
# 0                       1                     0.0                    6
# 1                       1                     0.0                    6
# 2                       1                     0.0                    6
# 3                       1                     0.0                    6
# 4                       1                     0.0                    6
# ...                   ...                     ...                  ...
# 16625                   0                     0.0                    7
# 16626                   0                     0.0                    7
# 16627                   0                     0.0                    7
# 16628                   0                     0.0                    7
# 16629                   0                     0.0                    7
#
#        num_docks_disabled  is_installed  is_renting  num_bikes_available  \
# 0                       0             1           1                    4
# 1                       0             1           1                    4
# 2                       0             1           1                    4
# 3                       0             1           1                    4
# 4                       0             1           1                    4
# ...                   ...           ...         ...                  ...
# 16625                   0             1           1                    2
# 16626                   0             1           1                    2
# 16627                   0             1           1                    2
# 16628                   0             1           1                    2
# 16629                   0             1           1                    2
#
#        num_scooters_unavailable  num_ebikes_available  \
# 0                           0.0                     0
# 1                           0.0                     0
# 2                           0.0                     0
# 3                           0.0                     0
# 4                           0.0                     0
# ...                         ...                   ...
# 16625                       0.0                     2
# 16626                       0.0                     2
# 16627                       0.0                     2
# 16628                       0.0                     2
# 16629                       0.0                     2
#
#                                  station_id  ...  n_scooters  \
# 0      a3b2862e-a135-11e9-9cda-0a87ae2ba916  ...           0
# 1      a3b2862e-a135-11e9-9cda-0a87ae2ba916  ...           0
# 2      a3b2862e-a135-11e9-9cda-0a87ae2ba916  ...           0
# 3      a3b2862e-a135-11e9-9cda-0a87ae2ba916  ...           0
# 4      a3b2862e-a135-11e9-9cda-0a87ae2ba916  ...           0
# ...                                     ...  ...         ...
# 16625                   1563698701206292480  ...           0
# 16626                   1563698701206292480  ...           0
# 16627                   1563698701206292480  ...           0
# 16628                   1563698701206292480  ...           0
# 16629                   1563698701206292480  ...           0
#
#             time_retrieved  is_no_classic  is_no_docks  is_problem_station  \
# 0      11/17/2023 01:05 AM          False        False               False
# 1      11/17/2023 02:07 AM          False        False               False
# 2      11/17/2023 03:06 AM          False        False               False
# 3      11/17/2023 04:06 AM          False        False               False
# 4      11/17/2023 05:05 AM          False        False               False
# ...                    ...            ...          ...                 ...
# 16625  11/17/2023 06:11 AM           True        False                True
# 16626  11/17/2023 07:09 AM           True        False                True
# 16627  11/17/2023 08:06 AM           True        False                True
# 16628  11/17/2023 09:06 AM           True        False                True
# 16629  11/17/2023 12:09 AM           True        False                True
#
#                           name        lat        lon  capacity is_public_rack
# 0        Bennett Ave & 79th St  41.751785 -87.578496        11          False
# 1        Bennett Ave & 79th St  41.751785 -87.578496        11          False
# 2        Bennett Ave & 79th St  41.751785 -87.578496        11          False
# 3        Bennett Ave & 79th St  41.751785 -87.578496        11          False
# 4        Bennett Ave & 79th St  41.751785 -87.578496        11          False
# ...                        ...        ...        ...       ...            ...
# 16625  Lamon Ave & Belmont Ave  41.939011 -87.749283         9          False
# 16626  Lamon Ave & Belmont Ave  41.939011 -87.749283         9          False
# 16627  Lamon Ave & Belmont Ave  41.939011 -87.749283         9          False
# 16628  Lamon Ave & Belmont Ave  41.939011 -87.749283         9          False
# 16629  Lamon Ave & Belmont Ave  41.939011 -87.749283         9          False
#
# [8890 rows x 24 columns]

# %% [markdown]
# # Export for analysis

# %%
df_stations_divvy.to_csv(f"../results/{filename_export}", index=False)
