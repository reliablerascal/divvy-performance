# %% [markdown]
# # Preliminary Analysis of Divvy Station Status
#
# 11/15/23<br>
# This notebook explores Divvy's API, to set the stage for subsequent data retrieval and analysis.<br>

# %% [markdown]
# <h3>Data mysteries</h3>
# <ul>
#     <li>figure out why num_ebikes_available does not always match vehicle_type_id = 2 (sometimes greater, sometimes less)</li>
#     <li>what do is_renting and is_returning mean?</li>
#     <li>how to identify lock vs. dock</li>
# </ul>

# %% [markdown]
# <h3>Documentation</h3>
# Live Station Data from Divvy Site
# https://gbfs.divvybikes.com/gbfs/2.3/gbfs.json

# %% [markdown]
# # import libraries

# %%
import pandas as pd
import requests
import datetime
import pytz

# %% [markdown]
# # review vehicle types

# %%
url = f"https://gbfs.lyft.com/gbfs/2.3/chi/en/vehicle_types.json?"

#run the query
response = requests.get(url)
data = response.json()
response
# Out:
# <Response [200]>

# %%
#navigate through dictionaries to find station data
#data.keys()
data['data'].keys()
# Out:
# dict_keys(['vehicle_types'])

# %%
central_tz = pytz.timezone('America/Chicago')
status_timestamp = datetime.datetime.utcfromtimestamp(data['last_updated']).replace(tzinfo=pytz.utc)
status_timestamp = status_timestamp.astimezone(central_tz).strftime('_%Y_%m_%d_%I%M%p')
status_timestamp
# Out:
# '_2023_11_20_1100AM'

# %%
#look at all data
data['data']['vehicle_types']
# Out:
# [{'form_factor': 'bicycle',
#   'vehicle_type_id': '1',
#   'propulsion_type': 'human'},
#  {'max_range_meters': 54717.56,
#   'form_factor': 'bicycle',
#   'vehicle_type_id': '2',
#   'propulsion_type': 'electric_assist'},
#  {'max_range_meters': 70810.95999999999,
#   'form_factor': 'scooter',
#   'vehicle_type_id': '3',
#   'propulsion_type': 'electric'}]

# %% [markdown]
# # review station info

# %%
url = f"https://gbfs.lyft.com/gbfs/2.3/chi/en/station_information.json?"

#request data
response = requests.get(url)
data = response.json()
response
# Out:
# <Response [200]>

# %%
#navigate through dictionaries to find station data
#data.keys()
data['data'].keys()
# Out:
# dict_keys(['stations'])

# %%
#look at the first station
data['data']['stations'][0]
# Out:
# {'lat': 41.916907,
#  'name': 'Parkside Ave & Armitage Ave',
#  'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#   'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#  'lon': -87.767173,
#  'short_name': '21354',
#  'station_id': '1871993715238611622',
#  'capacity': 15}

# %%
df_station_info = pd.DataFrame(data['data']['stations'], columns=['station_id','name','lat','lon','capacity','short_name'])
df_station_info.head()
# Out:
#                              station_id                         name  \
# 0                   1871993715238611622  Parkside Ave & Armitage Ave
# 1  a3a5de24-a135-11e9-9cda-0a87ae2ba916     Lincoln Ave & Melrose St
# 2  a3a7f0ba-a135-11e9-9cda-0a87ae2ba916       Damen Ave & Madison St
# 3  a3a62fc9-a135-11e9-9cda-0a87ae2ba916        Indiana Ave & 26th St
# 4  a3b4399a-a135-11e9-9cda-0a87ae2ba916                   Smith Park
#
#          lat        lon  capacity    short_name
# 0  41.916907 -87.767173        15         21354
# 1  41.940600 -87.669435        15  TA1309000042
# 2  41.881370 -87.674930        15         13134
# 3  41.845687 -87.622481        15  TA1307000005
# 4  41.892048 -87.689397        15           643

# %% [markdown]
# # review station status

# %% [markdown]
# ### review data structures

# %%
#run the query
url = f"https://gbfs.lyft.com/gbfs/2.3/chi/en/station_status.json?"
response = requests.get(url)
data = response.json()
response
# Out:
# <Response [200]>

# %%
#navigate through dictionaries to find station data
# data.keys()
data['data'].keys()
# Out:
# dict_keys(['stations'])

# %%
#look at the first station
data_station_status = data['data']['stations']
data_station_status[0]
# Out:
# {'vehicle_docks_available': [{'vehicle_type_ids': ['1', '2'], 'count': 0}],
#  'num_bikes_disabled': 0,
#  'num_docks_available': 0,
#  'num_docks_disabled': 0,
#  'is_installed': 0,
#  'is_renting': 0,
#  'last_reported': 86400,
#  'num_bikes_available': 0,
#  'vehicle_types_available': [{'count': 0, 'vehicle_type_id': '1'},
#   {'count': 0, 'vehicle_type_id': '2'}],
#  'num_ebikes_available': 0,
#  'station_id': '1871993715238611622',
#  'is_returning': 0}

# %%
#read into dataframe and rename columns
df_station_status= pd.DataFrame(data_station_status, columns=
        ['station_id','num_bikes_available','vehicle_docks_available',
         'vehicle_types_available','num_bikes_disabled','num_docks_available','num_ebikes_available'])

# %% [markdown]
# ### review vehicle type dictionary

# %%
#extract vehicle type info
df_station_status['n_classic'] = df_station_status['vehicle_types_available'].apply(
    lambda x: next((item['count'] for item in x if item['vehicle_type_id'] == '1'), 0))
df_station_status['n_electric'] = df_station_status['vehicle_types_available'].apply(
    lambda x: next((item['count'] for item in x if item['vehicle_type_id'] == '2'), 0))
df_station_status['n_scooters'] = df_station_status['vehicle_types_available'].apply(
    lambda x: next((item['count'] for item in x if item['vehicle_type_id'] == '3'), 0))

df_station_status[['station_id','n_classic','n_electric','n_scooters']].head()
# Out:
#                              station_id  n_classic  n_electric  n_scooters
# 0                   1871993715238611622          0           0           0
# 1  a3a5de24-a135-11e9-9cda-0a87ae2ba916          8           2           0
# 2  a3a7f0ba-a135-11e9-9cda-0a87ae2ba916          6           2           0
# 3  a3a62fc9-a135-11e9-9cda-0a87ae2ba916          9           1           1
# 4  a3b4399a-a135-11e9-9cda-0a87ae2ba916          4           1           0

# %% [markdown]
# ### review dock types dictionary

# %%
df_station_status['vehicle_docks_available']
# Out:
# 0          [{'vehicle_type_ids': ['1', '2'], 'count': 0}]
# 1          [{'vehicle_type_ids': ['1', '2'], 'count': 3}]
# 2       [{'vehicle_type_ids': ['1', '2', '3'], 'count'...
# 3       [{'vehicle_type_ids': ['1', '2', '3'], 'count'...
# 4          [{'vehicle_type_ids': ['1', '2'], 'count': 9}]
#                               ...
# 1662       [{'vehicle_type_ids': ['1', '2'], 'count': 0}]
# 1663       [{'vehicle_type_ids': ['1', '2'], 'count': 0}]
# 1664       [{'vehicle_type_ids': ['1', '2'], 'count': 0}]
# 1665       [{'vehicle_type_ids': ['1', '2'], 'count': 0}]
# 1666       [{'vehicle_type_ids': ['1', '2'], 'count': 0}]
# Name: vehicle_docks_available, Length: 1667, dtype: object

# %%
df_station_status['dock_type_ids'] = df_station_status[
    'vehicle_docks_available'].apply(lambda x: x[0]['vehicle_type_ids'] if x else None)
df_station_status['n_docks'] = df_station_status['vehicle_docks_available'].apply(lambda x: x[0]['count'] if x else None)

# %%
df_station_status[['station_id','dock_type_ids','n_docks']]
# Out:
#                                 station_id dock_type_ids  n_docks
# 0                      1871993715238611622        [1, 2]        0
# 1     a3a5de24-a135-11e9-9cda-0a87ae2ba916        [1, 2]        3
# 2     a3a7f0ba-a135-11e9-9cda-0a87ae2ba916     [1, 2, 3]        7
# 3     a3a62fc9-a135-11e9-9cda-0a87ae2ba916     [1, 2, 3]        4
# 4     a3b4399a-a135-11e9-9cda-0a87ae2ba916        [1, 2]        9
# ...                                    ...           ...      ...
# 1662                   1674190656158837882        [1, 2]        0
# 1663                   1674190428525570800        [1, 2]        0
# 1664                   1674190239547009458        [1, 2]        0
# 1665                   1806749727197839828        [1, 2]        0
# 1666                   1715846705501012842        [1, 2]        0
#
# [1667 rows x 3 columns]

# %%
#this is weird, and not so helpful
df_station_status['dock_type_ids'].value_counts()
# Out:
# dock_type_ids
# [1, 2]       1427
# [1, 2, 3]     240
# Name: count, dtype: int64

# %% [markdown]
# ### review lock-only stations

# %%
#review the 3 Humboldt Park stations with no classic bikes- Grand/Hamlin, Central Park/Augusta, Central Park/Ohio)
station_ids = ['1575949519568499428', '1575949510978564830', '1575949515273532128']
df_humboldt3 = df_station_status[df_station_status['station_id'].isin(station_ids)]
df_humboldt3.to_csv("../results/docks_humboldt3.csv")
df_station_status.to_csv("../results/docks_all.csv")

# %% [markdown]
# ### review station stats

# %%
#calculate station data
df_station_status['n_all_bikes']=df_station_status['num_bikes_available']+df_station_status['num_bikes_disabled']
df_station_status['is_no_classic']=(df_station_status['n_classic']==0)
df_station_status['is_no_docks']=(df_station_status['num_docks_available']==0)
df_station_status['is_problem_station']= df_station_status['is_no_classic'] | df_station_status['is_no_docks']
df_station_status['station_id_len']=df_station_status['station_id'].str.len()

df_station_status[['station_id','n_all_bikes','is_no_classic','is_no_docks','is_problem_station','station_id_len']].head()
# Out:
#                              station_id  n_all_bikes  is_no_classic  \
# 0                   1871993715238611622            0           True
# 1  a3a5de24-a135-11e9-9cda-0a87ae2ba916           12          False
# 2  a3a7f0ba-a135-11e9-9cda-0a87ae2ba916            8          False
# 3  a3a62fc9-a135-11e9-9cda-0a87ae2ba916           10          False
# 4  a3b4399a-a135-11e9-9cda-0a87ae2ba916            6          False
#
#    is_no_docks  is_problem_station  station_id_len
# 0         True                True              19
# 1        False               False              36
# 2        False               False              36
# 3        False               False              36
# 4        False               False              36

# %% [markdown]
# # Review Free Bikes
# this looks like only stray e-bikes and scooters with nothing re: classic bikes

# %%
url = f"https://gbfs.lyft.com/gbfs/2.3/chi/en/free_bike_status.json?"
response = requests.get(url)
data = response.json()
response
# Out:
# <Response [200]>

# %%
data['data']['bikes']
# Out:
# [{'lat': 41.80938783333333,
#   'bike_id': 'e25864fef418f4503f93a46fc88d0878',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.6200885,
#   'current_range_meters': 14323.161600000001},
#  {'lat': 41.960619,
#   'bike_id': 'ee0953947ea06873deb6e45884c91e06',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.76487366666667,
#   'current_range_meters': 40072.6656},
#  {'lat': 41.88539183333334,
#   'bike_id': 'd3c9b030d3ef88b936cf34df1bd6ed1c',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.726707,
#   'current_range_meters': 32830.6176},
#  {'lat': 41.87773116666666,
#   'bike_id': '032f67e8a6723c566d51a9360c9744bd',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.63424766666667,
#   'current_range_meters': 17863.7184},
#  {'lat': 41.997115,
#   'bike_id': '41cc34956f725692fe67cd6528556944',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.67015533333333,
#   'current_range_meters': 14805.9648},
#  {'lat': 41.979143666666666,
#   'bike_id': '419810fccd61f0522ca9fd57b6b7b18e',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.66832133333334,
#   'current_range_meters': 25105.7664},
#  {'lat': 41.94958666666667,
#   'bike_id': '33590551969a6be063ec92f09baaf4d9',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.7586425,
#   'current_range_meters': 21082.4064},
#  {'lat': 41.8188735,
#   'bike_id': '56a5fad2731b40c27997e6856aac5a2c',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.68714766666666,
#   'current_range_meters': 27841.6512},
#  {'lat': 41.83426983333333,
#   'bike_id': '145f8878e0b32c760781453dd0370cf8',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.67343466666667,
#   'current_range_meters': 19794.931200000003},
#  {'lat': 41.910415666666665,
#   'bike_id': '02fada8f152ca36029f5c56db44e0f74',
#   'is_disabled': 0,
#   'vehicle_type_id': '3',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.6732675,
#   'current_range_meters': 53913.024000000005},
#  {'lat': 41.8202895,
#   'bike_id': 'f0822c8f8078326c3a6625635e9b2e1c',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.59998,
#   'current_range_meters': 25588.569600000003},
#  {'lat': 41.759198,
#   'bike_id': '25e2381d634c98d0ceb99c394190d6b9',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.595747,
#   'current_range_meters': 17541.8496},
#  {'lat': 41.80571283333333,
#   'bike_id': '5014dae8781ec853ded590009290db65',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.62298133333333,
#   'current_range_meters': 33635.2896},
#  {'lat': 41.885485833333334,
#   'bike_id': 'ea992ab8a07d42158d76f938f6653022',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.65244466666667,
#   'current_range_meters': 22852.6848},
#  {'lat': 41.8357145,
#   'bike_id': '78ef5f1092cb6641490ddb5d616e244c',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.6389355,
#   'current_range_meters': 19312.128},
#  {'lat': 41.76641016666667,
#   'bike_id': 'e02a5762d0e069529afd0366c76acbc1',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.61157466666667,
#   'current_range_meters': 34118.0928},
#  {'lat': 41.97797966666667,
#   'bike_id': '23e29c0894277c7ad4a6a419e69481a2',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.668054,
#   'current_range_meters': 21565.209600000002},
#  {'lat': 41.98070666666667,
#   'bike_id': '09ec22973a2596d4fe09abafa0995943',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.67427616666667,
#   'current_range_meters': 23335.488},
#  {'lat': 41.94236033333333,
#   'bike_id': 'a80c6c6f0c3b763879d1a993935aca71',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.657786,
#   'current_range_meters': 31060.339200000002},
#  {'lat': 41.954956,
#   'bike_id': '74306c09cd0578a6228901ce197b1d88',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.7449345,
#   'current_range_meters': 40072.6656},
#  {'lat': 41.87371066666667,
#   'bike_id': '1df365cef38a7a8b9d3a7b7f84ec35ec',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.698751,
#   'current_range_meters': 34118.0928},
#  {'lat': 41.838998333333336,
#   'bike_id': '0d312a5778eca55f9be841746a10e275',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.64641366666666,
#   'current_range_meters': 28807.257599999997},
#  {'lat': 41.96868933333333,
#   'bike_id': 'a4ded9c42659b1b6a14bc1e52c00d449',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.6812785,
#   'current_range_meters': 37819.584},
#  {'lat': 41.875756333333335,
#   'bike_id': 'b06f895de21da9a304637668c76a425c',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.669175,
#   'current_range_meters': 35083.6992},
#  {'lat': 41.9242325,
#   'bike_id': '437ecc650d0220cc3d37258763a8150f',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.7782695,
#   'current_range_meters': 17863.7184},
#  {'lat': 41.917288666666664,
#   'bike_id': 'ba85eefd9f67cd6889b75194bcd63453',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.64614166666667,
#   'current_range_meters': 32830.6176},
#  {'lat': 41.8751065,
#   'bike_id': '8d90a422ce13b7873783a3c7968171b7',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.67552633333334,
#   'current_range_meters': 26071.3728},
#  {'lat': 41.80215,
#   'bike_id': '5582398100a9b512a07a1fd9d5ea6220',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.62256783333333,
#   'current_range_meters': 15288.768},
#  {'lat': 41.856473333333334,
#   'bike_id': 'a7a3269ff69dfb62ce6b7334ab33ad19',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.627508,
#   'current_range_meters': 23818.291200000003},
#  {'lat': 42.01192416666667,
#   'bike_id': '27acf14bc1e1f0062fe7d74cfd8faae3',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.7082915,
#   'current_range_meters': 32347.814400000003},
#  {'lat': 42.0328425,
#   'bike_id': '492b20de74790cc3c46b61a5ed713737',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.704084,
#   'current_range_meters': 23335.488},
#  {'lat': 41.76052683333333,
#   'bike_id': 'cca1d73df6eb907d5503e7300fb7536e',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.717589,
#   'current_range_meters': 33635.2896},
#  {'lat': 41.855017,
#   'bike_id': '91fd7db6a61261e35f77d8fcbea98040',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.675785,
#   'current_range_meters': 24622.963200000002},
#  {'lat': 41.882914666666665,
#   'bike_id': '8678ef0d5280a3ac3b73c6959f3725db',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.62595066666667,
#   'current_range_meters': 28324.454400000002},
#  {'lat': 41.9137535,
#   'bike_id': '64b9f545550c7d199303093beab39b74',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.748168,
#   'current_range_meters': 13357.5552},
#  {'lat': 41.8844355,
#   'bike_id': '7722a9e98c37cabfb339a0da07a33844',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.63531433333333,
#   'current_range_meters': 23335.488},
#  {'lat': 41.931932833333335,
#   'bike_id': 'd366926fc8affbfc3f0621cada6aef1d',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.69151933333333,
#   'current_range_meters': 31382.208000000002},
#  {'lat': 41.93202383333333,
#   'bike_id': '8e4a78543724f79f42a8b840ac612d63',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.683759,
#   'current_range_meters': 27841.6512},
#  {'lat': 41.90498633333333,
#   'bike_id': 'b605fff9945ec95c1ad217fd69df655f',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.62995166666667,
#   'current_range_meters': 15288.768},
#  {'lat': 41.900822,
#   'bike_id': '0a4b166991285c5bb04b0caf673bb839',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.713148,
#   'current_range_meters': 17541.8496},
#  {'lat': 41.906326166666666,
#   'bike_id': '04f9c4b1e17661a4e7c554f0f563e18d',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.64599,
#   'current_range_meters': 31382.208000000002},
#  {'lat': 41.72207133333333,
#   'bike_id': 'f8a4d8c72341bbd2aced5a5c58134717',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.57897433333333,
#   'current_range_meters': 21082.4064},
#  {'lat': 41.872688,
#   'bike_id': '41fe3fa8fad329608d01706ad21ced55',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.66914816666667,
#   'current_range_meters': 35566.502400000005},
#  {'lat': 41.93658466666667,
#   'bike_id': 'adb7b071bbbb8e16f8788b2c378c9559',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.6854325,
#   'current_range_meters': 23335.488},
#  {'lat': 41.927275333333334,
#   'bike_id': '77aefbad35ec7691123f35df3ab6ede7',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.704668,
#   'current_range_meters': 36853.9776},
#  {'lat': 41.85291933333333,
#   'bike_id': '2acb45cf02f12e3edf0722bb8a0a1604',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.65738233333333,
#   'current_range_meters': 28324.454400000002},
#  {'lat': 41.98919466666667,
#   'bike_id': '2bdc7ef1864c507656d482319c45ecbc',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.6746015,
#   'current_range_meters': 33313.4208},
#  {'lat': 41.89480983333333,
#   'bike_id': '19a90112ede6c6e6fc1f0f1928b11a19',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.62298483333333,
#   'current_range_meters': 15610.6368},
#  {'lat': 41.88318366666667,
#   'bike_id': '0dc850052019a246c8569d42cc719b83',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.62771483333333,
#   'current_range_meters': 36853.9776},
#  {'lat': 41.736085333333335,
#   'bike_id': '43f558089f93cc67b221c0d19f3b2581',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.644603,
#   'current_range_meters': 35888.3712},
#  {'lat': 41.9143405,
#   'bike_id': 'd6a57704069aaff93c05e0fdfa13a390',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.70855183333333,
#   'current_range_meters': 20599.6032},
#  {'lat': 41.85402583333333,
#   'bike_id': '2886a56eac13441f498cb2debd8bdab4',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.62699466666666,
#   'current_range_meters': 28807.257599999997},
#  {'lat': 42.009247,
#   'bike_id': 'f5688522eb2fe360671345903e5f0854',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.66354033333333,
#   'current_range_meters': 29611.9296},
#  {'lat': 41.736590666666665,
#   'bike_id': '4e0553d007873e51b749cc68e4efa3e9',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.62940133333333,
#   'current_range_meters': 27358.848},
#  {'lat': 41.895602333333336,
#   'bike_id': 'c0ad4b83572094072390fe6e5f60b3f8',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.709958,
#   'current_range_meters': 13357.5552},
#  {'lat': 41.888656,
#   'bike_id': '4e8fad5f01d86dee9785a8257a1d20a9',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.62825916666667,
#   'current_range_meters': 23335.488},
#  {'lat': 41.88225516666667,
#   'bike_id': '2d58f1501263f08cb617a671977807fb',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.63242166666667,
#   'current_range_meters': 40394.534400000004},
#  {'lat': 41.946689,
#   'bike_id': '5e38d4f7c0140da5564f17e0939589b1',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.81547983333333,
#   'current_range_meters': 13035.6864},
#  {'lat': 41.947407166666665,
#   'bike_id': '91595c2de75c699a0545885d3918747f',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.7091465,
#   'current_range_meters': 33635.2896},
#  {'lat': 41.96008966666667,
#   'bike_id': '60a58a1f6b401baf04e4e409b78c74ea',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.72162283333333,
#   'current_range_meters': 14805.9648},
#  {'lat': 41.8708785,
#   'bike_id': '5fc06df8026b777e6936f01559be4632',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.71355816666667,
#   'current_range_meters': 40394.534400000004},
#  {'lat': 41.8082105,
#   'bike_id': 'd29af93ef9d05750e51428b9bfe0973f',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.62614466666666,
#   'current_range_meters': 35083.6992},
#  {'lat': 41.902376,
#   'bike_id': 'c9d9e069690438859ebba55661c08ff3',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.64273,
#   'current_range_meters': 34118.0928},
#  {'lat': 41.96467416666667,
#   'bike_id': 'b8f4613a163e02fe6e8964413885e8aa',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.73493483333333,
#   'current_range_meters': 35083.6992},
#  {'lat': 41.76277366666667,
#   'bike_id': 'c81c56ace24227c05d24105fa3c65c2a',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.63723583333334,
#   'current_range_meters': 25105.7664},
#  {'lat': 41.9543245,
#   'bike_id': '38b05b4b459f8664842b1970b5976bc6',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.66567316666666,
#   'current_range_meters': 34118.0928},
#  {'lat': 41.86487966666667,
#   'bike_id': '9f51c8f8505c7c114646817fdee01c89',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.7105355,
#   'current_range_meters': 39589.862400000005},
#  {'lat': 41.93565183333333,
#   'bike_id': 'f065e0dda5a0a6a8fc4be6ea528709ff',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.70522266666667,
#   'current_range_meters': 38141.4528},
#  {'lat': 41.921914666666666,
#   'bike_id': '0cb7d5820965fadfa59f88ae40cbfaed',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.78925366666667,
#   'current_range_meters': 29611.9296},
#  {'lat': 41.9540875,
#   'bike_id': 'c1cad673125894b169a1224f701178cb',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.66413016666667,
#   'current_range_meters': 35888.3712},
#  {'lat': 41.893221,
#   'bike_id': '1c0ad7f224e37f2118d2666401fb6385',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.66096583333334,
#   'current_range_meters': 15288.768},
#  {'lat': 41.772350833333334,
#   'bike_id': '539abe13a5af89c52dce97225f5fd707',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.72070233333334,
#   'current_range_meters': 21565.209600000002},
#  {'lat': 41.805688833333335,
#   'bike_id': '8128a23060056f98e69a1e527a66590a',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.623198,
#   'current_range_meters': 17863.7184},
#  {'lat': 41.90975616666667,
#   'bike_id': '4122ef1f497ec6e9af94f1f59a472d66',
#   'is_disabled': 0,
#   'vehicle_type_id': '3',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.65203916666667,
#   'current_range_meters': 8690.457600000002},
#  {'lat': 41.8903165,
#   'bike_id': '8b525ac3feb16d58b5557215d089fd7d',
#   'is_disabled': 0,
#   'vehicle_type_id': '3',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.62150383333334,
#   'current_range_meters': 25105.7664},
#  {'lat': 41.898839,
#   'bike_id': '249eb5b11566d12a7069432ab20c64ef',
#   'is_disabled': 0,
#   'vehicle_type_id': '3',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.623762,
#   'current_range_meters': 64695.628800000006},
#  {'lat': 41.871387666666664,
#   'bike_id': '4d776021da47e7573ceb0487713f4c04',
#   'is_disabled': 0,
#   'vehicle_type_id': '3',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.6768235,
#   'current_range_meters': 31704.0768},
#  {'lat': 41.9613535,
#   'bike_id': 'c8112101c20e6d3462cf0681e628543a',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.69089766666667,
#   'current_range_meters': 36853.9776},
#  {'lat': 41.906216666666666,
#   'bike_id': 'd1261d1d5799ab0b723a93398c0cef7c',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.65042,
#   'current_range_meters': 14805.9648},
#  {'lat': 41.74989933333333,
#   'bike_id': '1d41d541b990c1d66dd355c65f8c47ec',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.57223333333333,
#   'current_range_meters': 22048.0128},
#  {'lat': 41.881160333333334,
#   'bike_id': '00e61729e8aa544e2dc60b6ee7d8ac24',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.6399825,
#   'current_range_meters': 34118.0928},
#  {'lat': 41.90325633333333,
#   'bike_id': '7fbc985f5a5701ce2b387f0354c827ae',
#   'is_disabled': 0,
#   'vehicle_type_id': '3',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.672996,
#   'current_range_meters': 71293.9392},
#  {'lat': 41.910636833333335,
#   'bike_id': 'b67a4c5eb4a202feb7ca6d8124397325',
#   'is_disabled': 0,
#   'vehicle_type_id': '3',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.67773466666667,
#   'current_range_meters': 70489.2672},
#  {'lat': 41.88447033333333,
#   'bike_id': 'dc59a4408fa6c27225a496a0f13a2d99',
#   'is_disabled': 0,
#   'vehicle_type_id': '3',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.63963633333333,
#   'current_range_meters': 68718.9888},
#  {'lat': 41.824059166666665,
#   'bike_id': '32bfbfbbe76565cc4c5b493020ed877b',
#   'is_disabled': 0,
#   'vehicle_type_id': '3',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.64094216666666,
#   'current_range_meters': 23657.3568},
#  {'lat': 41.835591,
#   'bike_id': '98f27bb3bc6ed0837308537b30c742fa',
#   'is_disabled': 0,
#   'vehicle_type_id': '3',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.67458183333333,
#   'current_range_meters': 39750.796800000004},
#  {'lat': 41.910513,
#   'bike_id': 'cd911d0b0fac1e3f9be935d35167b0d3',
#   'is_disabled': 0,
#   'vehicle_type_id': '3',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.67741833333334,
#   'current_range_meters': 66304.9728},
#  {'lat': 41.85307,
#   'bike_id': '93f15e41b201a8dbd91aae5cb53f00c6',
#   'is_disabled': 0,
#   'vehicle_type_id': '3',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.63515666666666,
#   'current_range_meters': 21887.0784},
#  {'lat': 41.86413666666667,
#   'bike_id': '9e0169cd4b51f01a11686fc4b9b640e9',
#   'is_disabled': 0,
#   'vehicle_type_id': '3',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.6756755,
#   'current_range_meters': 22691.7504},
#  {'lat': 41.863957166666665,
#   'bike_id': '581320f2b480cac0516e88f6543c58b2',
#   'is_disabled': 0,
#   'vehicle_type_id': '3',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.67992033333333,
#   'current_range_meters': 1126.5408},
#  {'lat': 41.8809175,
#   'bike_id': '05213348c2ad3285515ed210d0e22acb',
#   'is_disabled': 0,
#   'vehicle_type_id': '3',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.62222,
#   'current_range_meters': 9334.1952},
#  {'lat': 41.82942933333333,
#   'bike_id': '7f99b1a7c9c4707c581bb26a7c5706bc',
#   'is_disabled': 0,
#   'vehicle_type_id': '3',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.60649916666667,
#   'current_range_meters': 29933.798400000003},
#  {'lat': 41.838486833333334,
#   'bike_id': '5e05bcafe52fd0760370a36891888109',
#   'is_disabled': 0,
#   'vehicle_type_id': '3',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.62736116666666,
#   'current_range_meters': 25588.569600000003},
#  {'lat': 41.894580166666664,
#   'bike_id': '732676eb6b13fcb2f4f526dee659dbf4',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.62295866666666,
#   'current_range_meters': 37819.584},
#  {'lat': 41.942179833333334,
#   'bike_id': '6579be98bcc05d393529d13ae4922506',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.75437783333334,
#   'current_range_meters': 20116.8},
#  {'lat': 41.92954433333333,
#   'bike_id': '563a0f4c5c34f339dcf575ad54af2de5',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.75230633333334,
#   'current_range_meters': 13035.6864},
#  {'lat': 41.94075733333333,
#   'bike_id': '68ed37c065d668fa575f5449ffbad7ce',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.6639895,
#   'current_range_meters': 31382.208000000002},
#  {'lat': 41.96754383333333,
#   'bike_id': 'bd3d837a9764c5d091bb5f9a217bc713',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.77756,
#   'current_range_meters': 16093.44},
#  {'lat': 41.854234,
#   'bike_id': '91103d38d45ab6a318675501200974e2',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.69560883333334,
#   'current_range_meters': 31865.0112},
#  {'lat': 41.898305666666666,
#   'bike_id': '8ffd7223990af14623c33f0bf374d1a2',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.7188195,
#   'current_range_meters': 13840.3584},
#  {'lat': 41.918697333333334,
#   'bike_id': '64fd2b69fa56e025e858de9380f998fa',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.637637,
#   'current_range_meters': 23818.291200000003},
#  {'lat': 41.855934166666664,
#   'bike_id': 'ec2aa26721c3e018cd18108345aa4b34',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.67061516666666,
#   'current_range_meters': 33313.4208},
#  {'lat': 41.866076666666665,
#   'bike_id': '2e728b258f44fc9b13332e5c770e6b94',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.607347,
#   'current_range_meters': 20116.8},
#  {'lat': 41.93293633333333,
#   'bike_id': 'f540f668e28dc46eb21b87e721a2e9b4',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.80527933333333,
#   'current_range_meters': 29129.126400000005},
#  {'lat': 41.776001666666666,
#   'bike_id': '81ff7023f2eeb0293b32966fd4aadfe6',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.71029133333333,
#   'current_range_meters': 33635.2896},
#  {'lat': 41.773204,
#   'bike_id': 'e6a7b0e53680cecb9251ca91a8fb0cac',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.70293783333334,
#   'current_range_meters': 26554.176},
#  {'lat': 41.85773783333333,
#   'bike_id': 'd6cd38fd3bb493bba161929658fb36a4',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.66582416666667,
#   'current_range_meters': 22852.6848},
#  {'lat': 41.958073,
#   'bike_id': '36ecbda82f107aaed0fb30a12678ddb1',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.68150633333333,
#   'current_range_meters': 36853.9776},
#  {'lat': 41.7932785,
#   'bike_id': '2dde593f4f1dde9f37e715428bc13f9d',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.594478,
#   'current_range_meters': 13357.5552},
#  {'lat': 41.85795783333333,
#   'bike_id': '450af2a90f80668e2f0e5128a9bfe9f5',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.640896,
#   'current_range_meters': 20599.6032},
#  {'lat': 41.83885216666667,
#   'bike_id': '738ec8071f03ec213114de4d61cec17f',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.70985083333333,
#   'current_range_meters': 23818.291200000003},
#  {'lat': 41.921793,
#   'bike_id': '9c9b0f5a60210924fea22f30b97f9791',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.66476533333334,
#   'current_range_meters': 29129.126400000005},
#  {'lat': 41.88184183333333,
#   'bike_id': '1a153cd1907446ac6a5665f31e8ec20e',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.64130383333334,
#   'current_range_meters': 16576.2432},
#  {'lat': 41.935607,
#   'bike_id': '0f4605d762f3fb4551aa9cb0c0359046',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.66299733333334,
#   'current_range_meters': 36853.9776},
#  {'lat': 41.9172315,
#   'bike_id': '31ab6ebdf198cab8c59eec600584ee91',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.63441083333333,
#   'current_range_meters': 40394.534400000004},
#  {'lat': 41.904332333333336,
#   'bike_id': '251c7120faa0f394c84b8a7f5def300f',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.73222366666667,
#   'current_range_meters': 39589.862400000005},
#  {'lat': 41.84632333333333,
#   'bike_id': 'b5ff92f01063792e0f3e93fd3b3b6cb7',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.6566825,
#   'current_range_meters': 31865.0112},
#  {'lat': 41.97798183333333,
#   'bike_id': '55324526cf9195909fed2aea77f611f4',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.66787066666667,
#   'current_range_meters': 34118.0928},
#  {'lat': 41.762827,
#   'bike_id': '8f1f78d5a3162f6812910695e0c5fdad',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.6372525,
#   'current_range_meters': 32830.6176},
#  {'lat': 41.918161,
#   'bike_id': '21ebcc1dcfb4389b837793dc50c4df30',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.64617033333333,
#   'current_range_meters': 40394.534400000004},
#  {'lat': 41.811408166666666,
#   'bike_id': '56a7d14c3913e5217fd4ef605ad5ace8',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.6638935,
#   'current_range_meters': 40072.6656},
#  {'lat': 41.871489833333335,
#   'bike_id': '4d797826985a8af9da21a476646d91f5',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.66989716666667,
#   'current_range_meters': 36371.1744},
#  {'lat': 41.882308,
#   'bike_id': '572edc6abe74b2035b1dfb8117d43fa9',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.62701583333333,
#   'current_range_meters': 16576.2432},
#  {'lat': 41.910423,
#   'bike_id': '83206d8abc6224441d6b224c0126e834',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.67574933333333,
#   'current_range_meters': 40072.6656},
#  {'lat': 41.91818633333333,
#   'bike_id': 'a60fbb26711896816717cce3267aac06',
#   'is_disabled': 0,
#   'vehicle_type_id': '3',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.65948116666667,
#   'current_range_meters': 71293.9392},
#  {'lat': 41.89374316666667,
#   'bike_id': 'f71c30d559ac864bc167a5bb7b9dada9',
#   'is_disabled': 0,
#   'vehicle_type_id': '3',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.641689,
#   'current_range_meters': 49084.992},
#  {'lat': 41.91767683333333,
#   'bike_id': 'b5251eed825a15a8c20e731d6b2e8f8d',
#   'is_disabled': 0,
#   'vehicle_type_id': '3',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.67269166666667,
#   'current_range_meters': 60511.33440000001},
#  {'lat': 41.85388616666667,
#   'bike_id': '89c533b7478e0989549df085fd165aea',
#   'is_disabled': 0,
#   'vehicle_type_id': '3',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.63300183333334,
#   'current_range_meters': 49889.664000000004},
#  {'lat': 41.83470333333333,
#   'bike_id': '416d959e997713577da2f8c93e140b3a',
#   'is_disabled': 0,
#   'vehicle_type_id': '3',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.62587933333333,
#   'current_range_meters': 38785.19040000001},
#  {'lat': 41.8501215,
#   'bike_id': '9223e0ecbb192156aa18e6e999a1d257',
#   'is_disabled': 0,
#   'vehicle_type_id': '3',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.63995883333334,
#   'current_range_meters': 68718.9888},
#  {'lat': 41.91834133333333,
#   'bike_id': '40e770b13e799ea8d4ba095322d14019',
#   'is_disabled': 0,
#   'vehicle_type_id': '3',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.656908,
#   'current_range_meters': 70489.2672},
#  {'lat': 41.8706535,
#   'bike_id': 'fd145795be9c1097dac237e8bb0f0a36',
#   'is_disabled': 0,
#   'vehicle_type_id': '3',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.632626,
#   'current_range_meters': 12713.8176},
#  {'lat': 41.86332383333333,
#   'bike_id': 'ff7eb440783642efbb9f20460cf87ab9',
#   'is_disabled': 0,
#   'vehicle_type_id': '3',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.64480833333333,
#   'current_range_meters': 19312.128},
#  {'lat': 41.890470666666666,
#   'bike_id': '729a9720279b395aefa6ec58f36231a9',
#   'is_disabled': 0,
#   'vehicle_type_id': '3',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.61747516666667,
#   'current_range_meters': 36853.9776},
#  {'lat': 41.870169833333335,
#   'bike_id': '92c9162b9e810a1203f955c46a0aa524',
#   'is_disabled': 0,
#   'vehicle_type_id': '3',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.63947966666667,
#   'current_range_meters': 13679.424},
#  {'lat': 41.872776,
#   'bike_id': 'eb4d9eaaa6eea1c4e7ebcde6b5ed80bd',
#   'is_disabled': 0,
#   'vehicle_type_id': '3',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.669148,
#   'current_range_meters': 7402.9824},
#  {'lat': 41.83770916666667,
#   'bike_id': 'a9c34bfa4f7767c8a9bbb80d60a9e071',
#   'is_disabled': 0,
#   'vehicle_type_id': '3',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.62786233333334,
#   'current_range_meters': 66304.9728},
#  {'lat': 41.87298633333333,
#   'bike_id': 'b3dcafcbc1ad36ef086f39f5d9338db8',
#   'is_disabled': 0,
#   'vehicle_type_id': '3',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.66903316666667,
#   'current_range_meters': 51499.008},
#  {'lat': 41.871237,
#   'bike_id': '92b328953fc051dfc717f6eae0bc74e0',
#   'is_disabled': 0,
#   'vehicle_type_id': '3',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.62090916666666,
#   'current_range_meters': 67109.64480000001},
#  {'lat': 41.88365816666666,
#   'bike_id': '3cad8c2b14a34b90aa8a196ed37898c1',
#   'is_disabled': 0,
#   'vehicle_type_id': '3',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.626684,
#   'current_range_meters': 67914.3168},
#  {'lat': 41.901824166666664,
#   'bike_id': 'f3fe6fb26c60609e63cbe9d9b8d98c61',
#   'is_disabled': 0,
#   'vehicle_type_id': '3',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.62817583333333,
#   'current_range_meters': 26554.176},
#  {'lat': 41.856293,
#   'bike_id': '41f39b8a1c79aa42df0a9df61f9d4cb0',
#   'is_disabled': 0,
#   'vehicle_type_id': '3',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.62761583333334,
#   'current_range_meters': 53913.024000000005},
#  {'lat': 41.85956066666667,
#   'bike_id': '6a7673d4436ba1d479017441bcbf5218',
#   'is_disabled': 0,
#   'vehicle_type_id': '3',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.66990366666667,
#   'current_range_meters': 37175.8464},
#  {'lat': 41.87296416666667,
#   'bike_id': 'fe1bc6bdfb03d6edd43918fdf8ffd46e',
#   'is_disabled': 0,
#   'vehicle_type_id': '3',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.669104,
#   'current_range_meters': 56487.97440000001},
#  {'lat': 41.82935166666667,
#   'bike_id': '025113543acd59e13896df4159dadcb2',
#   'is_disabled': 0,
#   'vehicle_type_id': '3',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.606744,
#   'current_range_meters': 1609.344},
#  {'lat': 41.8641095,
#   'bike_id': 'c05bc1efcfb04df32d1093f763273149',
#   'is_disabled': 0,
#   'vehicle_type_id': '3',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.62579183333334,
#   'current_range_meters': 67109.64480000001},
#  {'lat': 41.88159566666667,
#   'bike_id': '0a804353fbdf0e03af124f8ae6571c8b',
#   'is_disabled': 0,
#   'vehicle_type_id': '3',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.63423416666667,
#   'current_range_meters': 20116.8},
#  {'lat': 41.890828166666665,
#   'bike_id': 'eb9cc26237522f016379a6cbc6ed366d',
#   'is_disabled': 0,
#   'vehicle_type_id': '3',
# ...
#   'lon': -87.75091233333333,
#   'current_range_meters': 35083.6992},
#  {'lat': 41.86762733333333,
#   'bike_id': '357b0b262b3cfa520377e1e6ef697748',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.62574633333334,
#   'current_range_meters': 26071.3728},
#  {'lat': 41.836540166666666,
#   'bike_id': '59c539353b76bfd6b827444048335e2f',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.6251285,
#   'current_range_meters': 26071.3728},
#  {'lat': 41.843722166666666,
#   'bike_id': '76202b733d565a23ecc8a311aabba44a',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.7124445,
#   'current_range_meters': 33635.2896},
#  {'lat': 41.936256666666665,
#   'bike_id': '11f043315e6e0235f3d0e8d357f9e600',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.7664675,
#   'current_range_meters': 18829.3248},
#  {'lat': 41.885525666666666,
#   'bike_id': '7bfe94640901f87746da0d775226a03b',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.6385475,
#   'current_range_meters': 11104.473600000001},
#  {'lat': 41.918419,
#   'bike_id': '7d31a1ce4871a978b46cec415c369b74',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.652191,
#   'current_range_meters': 29611.9296},
#  {'lat': 41.838916166666664,
#   'bike_id': '06e7228acd1986449ae3a8814dd28d42',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.7095245,
#   'current_range_meters': 17059.0464},
#  {'lat': 41.703124,
#   'bike_id': 'e711ec6ea640efec156762be391c6623',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.70132883333333,
#   'current_range_meters': 25105.7664},
#  {'lat': 41.9311845,
#   'bike_id': 'e14bdeeb778407f9392cc2a5905c7032',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.77561683333333,
#   'current_range_meters': 30577.536},
#  {'lat': 41.82768733333333,
#   'bike_id': '5a8b547f3c39fa6bad0e997b05856914',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.65934216666666,
#   'current_range_meters': 40072.6656},
#  {'lat': 41.89319166666667,
#   'bike_id': 'a41c2047e5e02b42d8d23b8f3b3a1d6b',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.625299,
#   'current_range_meters': 29129.126400000005},
#  {'lat': 41.8774465,
#   'bike_id': '551e4208253bd300f7f1dea2830685ab',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.67246883333334,
#   'current_range_meters': 25588.569600000003},
#  {'lat': 41.7986565,
#   'bike_id': '0948e1a5f3d85e26ebea4f7af3f4d487',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.7308135,
#   'current_range_meters': 26876.0448},
#  {'lat': 41.87287383333334,
#   'bike_id': '48db74a51cb1bfa849ce94688d95beec',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.66900266666667,
#   'current_range_meters': 27841.6512},
#  {'lat': 41.886793,
#   'bike_id': '31691fe417a6eb1233635e806292b918',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.62106466666667,
#   'current_range_meters': 20116.8},
#  {'lat': 41.8758765,
#   'bike_id': '8d3e909a07b13ce0692221711f23902d',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.62560033333334,
#   'current_range_meters': 33313.4208},
#  {'lat': 41.9556665,
#   'bike_id': '4f79b397000bb3e79828de1671b66a55',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.7429325,
#   'current_range_meters': 37336.7808},
#  {'lat': 41.6644755,
#   'bike_id': '0bc4b6f73f58c3211b144ab1680c1552',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.62200683333333,
#   'current_range_meters': 17863.7184},
#  {'lat': 41.929148,
#   'bike_id': 'd0f2191260d837f6b82b2a6a258f4a7e',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.64914116666667,
#   'current_range_meters': 40072.6656},
#  {'lat': 41.703219,
#   'bike_id': '217c73841446901e19a93986b6817096',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.559511,
#   'current_range_meters': 35888.3712},
#  {'lat': 41.77996483333333,
#   'bike_id': '044cc7b74dc320c6e267ea7b7e076bc6',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.59818583333333,
#   'current_range_meters': 17059.0464},
#  {'lat': 41.85422033333333,
#   'bike_id': '8cc3155d806efe601391f79332320a2f',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.70538883333333,
#   'current_range_meters': 40072.6656},
#  {'lat': 41.917055,
#   'bike_id': 'f6f3ab8273bad5e7ddeaa7dc5cd7c61e',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.71016983333334,
#   'current_range_meters': 33313.4208},
#  {'lat': 41.82339133333333,
#   'bike_id': '8dedadefef10ca13454cfb8890e6e098',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.66560733333333,
#   'current_range_meters': 21565.209600000002},
#  {'lat': 41.791653333333336,
#   'bike_id': '31f94b68c0ae53ac333ddebe63ebb2d5',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.59965333333334,
#   'current_range_meters': 11587.276800000001},
#  {'lat': 41.96465283333333,
#   'bike_id': '4297313aa2809f22c07b4a79b95a8d30',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.7277445,
#   'current_range_meters': 34600.896},
#  {'lat': 41.90061933333333,
#   'bike_id': 'ca5a4b6799875605cef0bff2b21c5646',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.712872,
#   'current_range_meters': 34600.896},
#  {'lat': 41.87769083333333,
#   'bike_id': 'b2529a1a3729c273ce3f73eaf5bfd42c',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.63089316666667,
#   'current_range_meters': 33313.4208},
#  {'lat': 41.8989615,
#   'bike_id': '8cca4579b52a6f1b0a10942584c991c1',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.620479,
#   'current_range_meters': 26876.0448},
#  {'lat': 41.78436116666666,
#   'bike_id': '8c7a7a9ec3a2ec95edbbb406df17f2d1',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.70314733333333,
#   'current_range_meters': 36371.1744},
#  {'lat': 41.930748666666666,
#   'bike_id': 'b7bedee4659c0ef1f8de95816cf6f833',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.67518066666666,
#   'current_range_meters': 38141.4528},
#  {'lat': 41.797796,
#   'bike_id': '20131e2487b70f5c04e0f930882f60f9',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.58410583333334,
#   'current_range_meters': 18829.3248},
#  {'lat': 41.885684833333336,
#   'bike_id': 'd6fbf020d3f976efc0f134e518b6e114',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.66212166666666,
#   'current_range_meters': 22852.6848},
#  {'lat': 41.872981833333334,
#   'bike_id': '3c9ee667380fab783ec9dec23315db0a',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.66885833333333,
#   'current_range_meters': 22369.8816},
#  {'lat': 41.929311166666665,
#   'bike_id': '38cf01f2396a9c76b70770af8568417a',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.6767865,
#   'current_range_meters': 16576.2432},
#  {'lat': 41.977547333333334,
#   'bike_id': 'f6ed8ace1766156ead3d9f303eb08eb7',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.6919125,
#   'current_range_meters': 33635.2896},
#  {'lat': 41.9107275,
#   'bike_id': 'cdb92bf2eb3515220459c0e1f5fd4bc8',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.67263166666666,
#   'current_range_meters': 34600.896},
#  {'lat': 41.87974916666667,
#   'bike_id': 'b78ac54582d8a41a6ceaefbcfe948f72',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.64936366666667,
#   'current_range_meters': 35083.6992},
#  {'lat': 41.91752,
#   'bike_id': '6184aebae67540116bdd1eaaf076ecd3',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.63771,
#   'current_range_meters': 24301.0944},
#  {'lat': 41.77755,
#   'bike_id': '5da920fffb3ffff17abb419c5f45da32',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.7076755,
#   'current_range_meters': 18346.5216},
#  {'lat': 41.91924866666667,
#   'bike_id': '6d0a0349c1c5f17ad010eaaf2153baf0',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.768614,
#   'current_range_meters': 31382.208000000002},
#  {'lat': 41.948696166666664,
#   'bike_id': '4ab44ee72d72b1958763ed0abac4793b',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.67538333333333,
#   'current_range_meters': 20599.6032},
#  {'lat': 41.940295666666664,
#   'bike_id': '746db6b12a1d126119595b83a17af12f',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.644395,
#   'current_range_meters': 19794.931200000003},
#  {'lat': 41.890945333333335,
#   'bike_id': 'bdeca885e5212140139c41caf631d93e',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.67332166666667,
#   'current_range_meters': 16093.44},
#  {'lat': 41.920824333333336,
#   'bike_id': 'ca749e6e52f426acc83d61d2c86b7828',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.73043333333334,
#   'current_range_meters': 13840.3584},
#  {'lat': 41.89100066666666,
#   'bike_id': '98a317f4408d439f13542178e2af40c8',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.609728,
#   'current_range_meters': 9816.9984},
#  {'lat': 41.885785166666665,
#   'bike_id': 'dbfc5cf744902042d0813ae858cce402',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.68078816666667,
#   'current_range_meters': 17059.0464},
#  {'lat': 41.93819716666667,
#   'bike_id': '432c68a2916c69eae386abe686cfec88',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.727936,
#   'current_range_meters': 38141.4528},
#  {'lat': 41.83821966666667,
#   'bike_id': '66fbc476563ee7cfd76a90f017fb7702',
#   'is_disabled': 0,
#   'vehicle_type_id': '2',
#   'is_reserved': 0,
#   'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#    'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#   'lon': -87.70543933333333,
#   'current_range_meters': 35888.3712},
#  ...]

# %%
df_bikes=pd.DataFrame(data['data']['bikes'])
df_bikes.head()
# Out:
#          lat                           bike_id  is_disabled vehicle_type_id  \
# 0  41.809388  e25864fef418f4503f93a46fc88d0878            0               2
# 1  41.960619  ee0953947ea06873deb6e45884c91e06            0               2
# 2  41.885392  d3c9b030d3ef88b936cf34df1bd6ed1c            0               2
# 3  41.877731  032f67e8a6723c566d51a9360c9744bd            0               2
# 4  41.997115  41cc34956f725692fe67cd6528556944            0               2
#
#    is_reserved                                        rental_uris        lon  \
# 0            0  {'android': 'https://chi.lft.to/lastmile_qr_sc... -87.620088
# 1            0  {'android': 'https://chi.lft.to/lastmile_qr_sc... -87.764874
# 2            0  {'android': 'https://chi.lft.to/lastmile_qr_sc... -87.726707
# 3            0  {'android': 'https://chi.lft.to/lastmile_qr_sc... -87.634248
# 4            0  {'android': 'https://chi.lft.to/lastmile_qr_sc... -87.670155
#
#    current_range_meters
# 0            14323.1616
# 1            40072.6656
# 2            32830.6176
# 3            17863.7184
# 4            14805.9648

# %%
df_bikes['vehicle_type_id'].value_counts()
# Out:
# vehicle_type_id
# 2    1705
# 3     343
# Name: count, dtype: int64

# %% [markdown]
# # Merge Station Info
# to assist with further exploration, esp. public racks and dock types

# %%
df_stations = pd.merge(df_station_status, df_station_info, on='station_id')
df_stations.head()
# Out:
#                              station_id  num_bikes_available  \
# 0  a3a565b1-a135-11e9-9cda-0a87ae2ba916                    6
# 1  a3b29fae-a135-11e9-9cda-0a87ae2ba916                    2
# 2  4843d153-c725-4230-a4c7-402da6a62143                   11
# 3  a3afb401-a135-11e9-9cda-0a87ae2ba916                    4
# 4  a3acea44-a135-11e9-9cda-0a87ae2ba916                    4
#
#                              vehicle_docks_available  \
# 0  [{'vehicle_type_ids': ['1', '2', '3'], 'count'...
# 1     [{'vehicle_type_ids': ['1', '2'], 'count': 9}]
# 2     [{'vehicle_type_ids': ['1', '2'], 'count': 2}]
# 3    [{'vehicle_type_ids': ['1', '2'], 'count': 11}]
# 4     [{'vehicle_type_ids': ['1', '2'], 'count': 6}]
#
#                              vehicle_types_available  num_bikes_disabled  \
# 0  [{'count': 5, 'vehicle_type_id': '1'}, {'count...                   0
# 1  [{'count': 2, 'vehicle_type_id': '1'}, {'count...                   0
# 2  [{'count': 10, 'vehicle_type_id': '1'}, {'coun...                   0
# 3  [{'count': 4, 'vehicle_type_id': '1'}, {'count...                   0
# 4  [{'count': 3, 'vehicle_type_id': '1'}, {'count...                   1
#
#    num_docks_available  num_ebikes_available  n_classic  n_electric  \
# 0                    0                     1          5           1
# 1                    9                     0          2           0
# 2                    2                     1         10           1
# 3                   11                     0          4           0
# 4                    6                     1          3           1
#
#    n_scooters  ... n_all_bikes  is_no_classic  is_no_docks  \
# 0           0  ...           6          False         True
# 1           0  ...           2          False        False
# 2           0  ...          11          False        False
# 3           0  ...           4          False        False
# 4           0  ...           5          False        False
#
#    is_problem_station  station_id_len                             name  \
# 0                True              36             Halsted St & Polk St
# 1               False              36       Stony Island Ave & 82nd St
# 2               False              36         Lincoln Ave & Roscoe St*
# 3               False              36  Monticello Ave & Irving Park Rd
# 4               False              36            Calumet Ave & 71st St
#
#          lat        lon  capacity    short_name
# 0  41.871840 -87.646640        19  TA1307000121
# 1  41.746559 -87.586005        11           583
# 2  41.943350 -87.670668        15  chargingstx5
# 3  41.954005 -87.719128        15  KA1504000139
# 4  41.765508 -87.616918        11         15599
#
# [5 rows x 22 columns]

# %%
#identify and remove public racks
df_stations['is_public_rack']=df_stations['name'].str[:11]=='Public Rack'

# %%
df_station_maps = df_stations[['station_id','name','dock_type_ids','is_public_rack','capacity','lat','lon']]
df_station_maps
# Out:
#                                 station_id  \
# 0     a3a565b1-a135-11e9-9cda-0a87ae2ba916
# 1     a3b29fae-a135-11e9-9cda-0a87ae2ba916
# 2     4843d153-c725-4230-a4c7-402da6a62143
# 3     a3afb401-a135-11e9-9cda-0a87ae2ba916
# 4     a3acea44-a135-11e9-9cda-0a87ae2ba916
# ...                                    ...
# 1661                   1715823822654071770
# 1662                   1563698701206292480
# 1663                   1674190591734328324
# 1664                   1806749735787774444
# 1665                   1674190634684001360
#
#                                           name dock_type_ids  is_public_rack  \
# 0                         Halsted St & Polk St     [1, 2, 3]           False
# 1                   Stony Island Ave & 82nd St        [1, 2]           False
# 2                     Lincoln Ave & Roscoe St*        [1, 2]           False
# 3              Monticello Ave & Irving Park Rd        [1, 2]           False
# 4                        Calumet Ave & 71st St        [1, 2]           False
# ...                                        ...           ...             ...
# 1661        Public Rack - Oakley Ave & 50th Pl        [1, 2]            True
# 1662                   Lamon Ave & Belmont Ave        [1, 2]           False
# 1663           Public Rack - Racine Ave & 76th        [1, 2]            True
# 1664  Public Rack - Central Ave & Lawrence Ave        [1, 2]            True
# 1665      Public Rack - Torrence Ave & 98th St        [1, 2]            True
#
#       capacity        lat        lon
# 0           19  41.871840 -87.646640
# 1           11  41.746559 -87.586005
# 2           15  41.943350 -87.670668
# 3           15  41.954005 -87.719128
# 4           11  41.765508 -87.616918
# ...        ...        ...        ...
# 1661         1  41.801930 -87.680903
# 1662         9  41.939011 -87.749283
# 1663         2  41.755786 -87.654054
# 1664         4  41.967864 -87.767593
# 1665         2  41.717059 -87.559986
#
# [1666 rows x 7 columns]

# %%
df_station_maps.to_csv('../results/station_map.csv')
